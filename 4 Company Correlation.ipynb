# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/BMW.DE 3.csv')

# %%
df = df.drop(columns=['Date'])

# %%
df
# Out:
#        Hyundai  RollRoyce         BMW        Bosch
# 0    36.490002       1.08   80.629997  14627.40039
# 1    36.299999       1.14   82.330002  14537.25000
# 2    38.349998       1.16   82.330002  14764.90039
# 3    37.500000       1.15   82.330002  14347.29981
# 4    36.549999       1.19   83.580002  14370.09961
# ..         ...        ...         ...          ...
# 230  40.900002       1.90  103.379997  18884.19922
# 231  41.939999       1.91  104.040001  18830.19922
# 232  41.750000       1.78  102.599998  18751.25000
# 233  40.500000       1.80  102.779999  18781.15039
# 234  40.750000       1.80  104.459999  18941.69922
#
# [235 rows x 4 columns]

# %%
import seaborn as sns

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
 
scaler = MinMaxScaler()
 
df_scaled = scaler.fit_transform(df.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
  'Hyundai', 'RollRoyce', 'BMW', 'Bosch'])
 
print("Scaled Dataset Using MinMaxScaler")
df_scaled.head()
# Out:
# Scaled Dataset Using MinMaxScaler
#     Hyundai  RollRoyce       BMW     Bosch
# 0  0.633737   0.282051  0.289017  0.200609
# 1  0.620968   0.333333  0.331742  0.186672
# 2  0.758736   0.350427  0.331742  0.221866
# 3  0.701613   0.341880  0.331742  0.157307
# 4  0.637769   0.376068  0.363157  0.160832

# %%
sns.pairplot(df_scaled)
# to show
plt.show()

# %%
df_scaled['Bosch'].corr(df_scaled['BMW'])
# Out:
# 0.7195511810395996

# %%
df_scaled['RollRoyce'].corr(df_scaled['Hyundai'])
# Out:
# 0.682021646760785

# %%
df_scaled['Bosch'].corr(df_scaled['RollRoyce'])
# Out:
# 0.7058025125551293
